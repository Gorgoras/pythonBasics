# %%
import pandas as pd

# %%
df = pd.read_csv(filepath_or_buffer='unificado.csv', sep='|')

# %%
display(df)
# Out:
#     Unnamed: 0  CustomerID  NameStyle Title    FirstName MiddleName  \
# 0            0           1      False   Mr.      Orlando         N.
# 1            1           2      False   Mr.        Keith        NaN
# 2            2           3      False   Ms.        Donna         F.
# 3            3           4      False   Ms.        Janet         M.
# 4            4           5      False   Mr.         Lucy        NaN
# 5            5           6      False   Ms.     Rosmarie         J.
# 6            6           7      False   Mr.      Dominic         P.
# 7            7          10      False   Ms.     Kathleen         M.
# 8            8          11      False   Ms.    Katherine        NaN
# 9            9          12      False   Mr.       Johnny         A.
# 10          10          16      False   Mr.  Christopher         R.
# 11          11          18      False   Mr.        David         J.
# 12          12          19      False   Mr.         John         A.
# ...
